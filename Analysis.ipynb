# %%
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-03-2020.csv')
df.head(10)
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-04-03 22:46:37
# 1  22001.0     Acadia       Louisiana             US  2020-04-03 22:46:37
# 2  51001.0   Accomack        Virginia             US  2020-04-03 22:46:37
# 3  16001.0        Ada           Idaho             US  2020-04-03 22:46:37
# 4  19001.0      Adair            Iowa             US  2020-04-03 22:46:37
# 5  29001.0      Adair        Missouri             US  2020-04-03 22:46:37
# 6  40001.0      Adair        Oklahoma             US  2020-04-03 22:46:37
# 7   8001.0      Adams        Colorado             US  2020-04-03 22:46:37
# 8  16003.0      Adams           Idaho             US  2020-04-03 22:46:37
# 9  17001.0      Adams        Illinois             US  2020-04-03 22:46:37
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          6       0          0       0
# ...

# %%
df.shape

# %%
#04/02: 2312, 12
usa = df[df['Country_Region'] == 'US']
usa.shape
# Out:
# (2368, 12)

# %%
#04/02 243453
#04/03 275586
usa.groupby('Country_Region')['Confirmed'].sum()
# Out:
# Country_Region
# US    275586
# Name: Confirmed, dtype: int64

# %%
#04/02 5926
#04/03 7087
usa.groupby('Country_Region')['Deaths'].sum()
# Out:
# Country_Region
# US    7087
# Name: Deaths, dtype: int64

# %%
#04/02, confirmed 826, deaths 21
#04/02, confirmed 899, deaths 22
usa[usa['Province_State'] == 'Oregon'].groupby('Province_State')['Confirmed','Deaths'].sum()
# Out:
#                 Confirmed  Deaths
# Province_State
# Oregon                899      22

# %%
usa[usa['Province_State'] == 'Oregon'].groupby('Province_State')['Deaths'].sum()
# Out:
# Province_State
# Oregon    21
# Name: Deaths, dtype: int64

# %%
usa[usa['Province_State'] == 'Oregon']
# Out:
#          FIPS      Admin2 Province_State Country_Region          Last_Update  \
# 118   41001.0       Baker         Oregon             US  2020-03-30 22:52:45
# 186   41003.0      Benton         Oregon             US  2020-03-30 22:52:45
# 512   41005.0   Clackamas         Oregon             US  2020-03-30 22:52:45
# 537   41007.0     Clatsop         Oregon             US  2020-03-30 22:52:45
# 609   41009.0    Columbia         Oregon             US  2020-03-30 22:52:45
# 633   41011.0        Coos         Oregon             US  2020-03-30 22:52:45
# 673   41013.0       Crook         Oregon             US  2020-03-30 22:52:45
# 693   41015.0       Curry         Oregon             US  2020-03-30 22:52:45
# 771   41017.0   Deschutes         Oregon             US  2020-03-30 22:52:45
# 814   41019.0     Douglas         Oregon             US  2020-03-30 22:52:45
# 1042  41021.0     Gilliam         Oregon             US  2020-03-30 22:52:45
# ...

# %%
usa[usa['Province_State'] == 'Oregon'].groupby(['Province_State'])['Confirmed'].sum()
# Out:
# Province_State
# Oregon    606
# Name: Confirmed, dtype: int64

# %%
usa.groupby(['Province_State'])['Confirmed'].sum()
# Out:
# Province_State
# Alabama                       899
# Alaska                        114
# American Samoa                  0
# Arizona                      1157
# Arkansas                      473
# California                   7138
# Colorado                     2311
# Connecticut                  2571
# Delaware                      264
# Diamond Princess               49
# District of Columbia          401
# Florida                      5473
# Georgia                      2808
# Grand Princess                103
# Guam                           58
# Hawaii                        175
# Idaho                         340
# Illinois                     5056
# Indiana                      1786
# Iowa                          424
# Kansas                        372
# Kentucky                      479
# Louisiana                    4025
# Maine                         275
# Maryland                     1413
# Massachusetts                5752
# Michigan                     6498
# ...

# %%
flu = pd.read_csv('/Users/dineshmurali/Documents/FluViewPhase2Data/ILINet.csv')
flu.shape
# Out:
# (1174, 1)

# %%
flu.head(10)
# Out:
#                                                                                                                                              PERCENTAGE OF VISITS FOR INFLUENZA-LIKE-ILLNESS REPORTED BY SENTINEL PROVIDERS
# REGION TYPE REGION YEAR WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS                                     TOTAL PATIENTS
# National    X      1997 40   1.10148        1.21686         179     X         157       205      X         29     570      192                                                            46842
#                         41   1.20007        1.28064         199     X         151       242      X         23     615      191                                                            48023
#                         42   1.37876        1.23906         228     X         153       266      X         34     681      219                                                            54961
# ...

# %%
fluClin = pd.read_csv('/Users/dineshmurali/Documents/FluViewPhase2Data/WHO_NREVSS_Clinical_Labs.csv')
fluClin.head(10)
# Out:
#                                                                                         *Beginning for the 2015-16 season, reports from public health and clinical laboratories are presented separately in the weekly influenza update, FluView. Data from clinical laboratories include the weekly total number of specimens tested, the number of positive influenza test, and the percent positive by influenza type.
# REGION TYPE REGION YEAR WEEK TOTAL SPECIMENS TOTAL A TOTAL B PERCENT POSITIVE PERCENT A                                          PERCENT B
# National    X      2015 40   12029           84      43      1.05578          0.698312                                            0.357469
#                         41   13111           116     54      1.29662          0.884753                                            0.411868
#                         42   13441           97      52      1.10855          0.721672                                            0.386876
# ...

# %%
#https://gis.cdc.gov/grasp/fluview/FluViewPhase2QuickReferenceGuide.pdf
fluStates = pd.read_csv('/Users/dineshmurali/Documents/FluViewPhase2DataAllStates/ILINet.csv')
fluStates.head(100)
# Out:
#                                                                                                                                                            PERCENTAGE OF VISITS FOR INFLUENZA-LIKE-ILLNESS REPORTED BY SENTINEL PROVIDERS
# REGION TYPE REGION               YEAR WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS                                     TOTAL PATIENTS
# States      Alabama              2010 40   X              2.13477         X       X         X         X        X         X      249      35                                                             11664
#             Alaska               2010 40   X              0.875146        X       X         X         X        X         X      15       7                                                               1714
# ...

# %%
fluStates.shape
# Out:
# (26494, 1)

# %%
fluStates.shape
# Out:
# (26494, 1)

# %%
fluStates.dtypes
# Out:
# PERCENTAGE OF VISITS FOR INFLUENZA-LIKE-ILLNESS REPORTED BY SENTINEL PROVIDERS    object
# dtype: object

# %%
fluAllSts = fluStates.reset_index()
fluAllSts.head(100)
# Out:
#         level_0               level_1 level_2 level_3         level_4  \
# 0   REGION TYPE                REGION    YEAR    WEEK  % WEIGHTED ILI
# 1        States               Alabama    2010      40               X
# 2        States                Alaska    2010      40               X
# 3        States               Arizona    2010      40               X
# 4        States              Arkansas    2010      40               X
# 5        States            California    2010      40               X
# 6        States              Colorado    2010      40               X
# 7        States           Connecticut    2010      40               X
# 8        States              Delaware    2010      40               X
# 9        States  District of Columbia    2010      40               X
# 10       States               Florida    2010      40               X
# 11       States               Georgia    2010      40               X
# ...

# %%
fluAllSts[1:]
# Out:
#       level_0                                       level_1 level_2 level_3  \
# 1      States                                       Alabama    2010      40
# 2      States                                        Alaska    2010      40
# 3      States                                       Arizona    2010      40
# 4      States                                      Arkansas    2010      40
# 5      States                                    California    2010      40
# 6      States                                      Colorado    2010      40
# 7      States                                   Connecticut    2010      40
# 8      States                                      Delaware    2010      40
# 9      States                          District of Columbia    2010      40
# 10     States                                       Florida    2010      40
# 11     States                                       Georgia    2010      40
# ...

# %%
fluAllSts.iloc[0]
# Out:
# level_0                                                                                 REGION TYPE
# level_1                                                                                      REGION
# level_2                                                                                        YEAR
# level_3                                                                                        WEEK
# level_4                                                                              % WEIGHTED ILI
# level_5                                                                             %UNWEIGHTED ILI
# level_6                                                                                     AGE 0-4
# level_7                                                                                   AGE 25-49
# level_8                                                                                   AGE 25-64
# ...

# %%
fluFinal = fluAllSts[1:].copy()
fluFinal.head(10)
# Out:
#    level_0               level_1 level_2 level_3 level_4    level_5 level_6  \
# 1   States               Alabama    2010      40       X    2.13477       X
# 2   States                Alaska    2010      40       X   0.875146       X
# 3   States               Arizona    2010      40       X   0.674721       X
# 4   States              Arkansas    2010      40       X   0.696056       X
# 5   States            California    2010      40       X    1.95412       X
# 6   States              Colorado    2010      40       X   0.660684       X
# 7   States           Connecticut    2010      40       X  0.0783085       X
# 8   States              Delaware    2010      40       X   0.100125       X
# 9   States  District of Columbia    2010      40       X    2.80877       X
# 10  States               Florida    2010      40       X          X       X
#
#    level_7 level_8 level_9 level_10 level_11 level_12 level_13  \
# 1        X       X       X        X        X      249       35
# ...

# %%
fluFinal.columns = fluAllSts.iloc[0]

# %%
fluFinal.head(10)
# Out:
# 0  REGION TYPE                REGION  YEAR WEEK % WEIGHTED ILI  \
# 1       States               Alabama  2010   40              X
# 2       States                Alaska  2010   40              X
# 3       States               Arizona  2010   40              X
# 4       States              Arkansas  2010   40              X
# 5       States            California  2010   40              X
# 6       States              Colorado  2010   40              X
# 7       States           Connecticut  2010   40              X
# 8       States              Delaware  2010   40              X
# 9       States  District of Columbia  2010   40              X
# 10      States               Florida  2010   40              X
#
# 0  %UNWEIGHTED ILI AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65  \
# 1          2.13477       X         X         X        X         X      X
# 2         0.875146       X         X         X        X         X      X
# ...

# %%
fluFinal['YEAR'] = fluFinal['YEAR'].fillna(1753)

# %%
fluFinal['YEAR'] = fluFinal['YEAR'].astype('int64')

# %%
fluFinal[fluFinal['YEAR'] >= 2015].head(50)
# Out:
# 0     REGION TYPE                REGION  YEAR WEEK % WEIGHTED ILI  \
# 11781      States               Alabama  2015    1              X
# 11782      States                Alaska  2015    1              X
# 11783      States               Arizona  2015    1              X
# 11784      States              Arkansas  2015    1              X
# 11785      States            California  2015    1              X
# 11786      States              Colorado  2015    1              X
# 11787      States           Connecticut  2015    1              X
# 11788      States              Delaware  2015    1              X
# 11789      States  District of Columbia  2015    1              X
# 11790      States               Florida  2015    1              X
# 11791      States               Georgia  2015    1              X
# 11792      States                Hawaii  2015    1              X
# 11793      States                 Idaho  2015    1              X
# ...

# %%
noAgeCols =[col for col in fluFinal.columns if not col.startswith('AGE')]
noAgeCols
# Out:
# ['REGION TYPE',
#  'REGION',
#  'YEAR',
#  'WEEK',
#  '% WEIGHTED ILI',
#  '%UNWEIGHTED ILI',
#  'ILITOTAL',
#  'NUM. OF PROVIDERS',
#  'TOTAL PATIENTS']

# %%
noAgeCols.remove('% WEIGHTED ILI')
noAgeCols
# Out:
# ['REGION TYPE',
#  'REGION',
#  'YEAR',
#  'WEEK',
#  '%UNWEIGHTED ILI',
#  'ILITOTAL',
#  'NUM. OF PROVIDERS',
#  'TOTAL PATIENTS']

# %%
fluFinal

# %%
#https://www.kff.org/medicaid/issue-brief/status-of-state-medicaid-expansion-decisions-interactive-map/
medicaidExp = pd.read_csv('medicaidexpansionmap.csv')
medicaidExp
# Out:
#                    State             Expansion Status  \
# 0                Alabama                  Not Adopted
# 1                 Alaska      Adopted and Implemented
# 2                Arizona      Adopted and Implemented
# 3               Arkansas      Adopted and Implemented
# 4             California      Adopted and Implemented
# 5               Colorado      Adopted and Implemented
# 6            Connecticut      Adopted and Implemented
# 7               Delaware      Adopted and Implemented
# 8   District of Columbia      Adopted and Implemented
# 9                Florida                  Not Adopted
# 10               Georgia                  Not Adopted
# 11                Hawaii      Adopted and Implemented
# 12                 Idaho      Adopted and Implemented
# 13              Illinois      Adopted and Implemented
# 14               Indiana      Adopted and Implemented
# 15                  Iowa      Adopted and Implemented
# ...

# %%
medicaidExp.fillna('NA', inplace=True)

# %%
dfimpdt = medicaidExp['Description'].str.extract('(\d+/\d+/\d+)')

# %%
dfimpdt[0]
# Out:
# 0           NaN
# 1      9/1/2015
# 2      1/1/2014
# 3      1/1/2014
# 4      1/1/2014
# 5      1/1/2014
# 6      1/1/2014
# 7      1/1/2014
# 8      1/1/2014
# 9           NaN
# 10          NaN
# 11     1/1/2014
# 12     1/1/2020
# 13     1/1/2014
# 14     2/1/2015
# 15     1/1/2014
# 16          NaN
# 17     1/1/2014
# 18     7/1/2016
# 19    1/10/2019
# 20     1/1/2014
# 21     1/1/2014
# 22     4/1/2014
# 23     1/1/2014
# 24          NaN
# 25          NaN
# 26     1/1/2016
# 27          NaN
# 28     1/1/2014
# 29    8/15/2014
# 30     1/1/2014
# 31     1/1/2014
# 32     1/1/2014
# 33          NaN
# 34     1/1/2014
# 35     1/1/2014
# 36          NaN
# 37     1/1/2014
# 38     1/1/2015
# 39     1/1/2014
# 40          NaN
# 41          NaN
# 42          NaN
# 43          NaN
# 44     1/1/2020
# 45     1/1/2014
# 46     1/1/2019
# 47     1/1/2014
# 48     1/1/2014
# 49          NaN
# 50          NaN
# Name: 0, dtype: object

# %%
medicaidExp['Implemented_Dt'] = pd.to_datetime(dfimpdt[0])

# %%
medicaidExp
# Out:
#                    State             Expansion Status  \
# 0                Alabama                  Not Adopted
# 1                 Alaska      Adopted and Implemented
# 2                Arizona      Adopted and Implemented
# 3               Arkansas      Adopted and Implemented
# 4             California      Adopted and Implemented
# 5               Colorado      Adopted and Implemented
# 6            Connecticut      Adopted and Implemented
# 7               Delaware      Adopted and Implemented
# 8   District of Columbia      Adopted and Implemented
# 9                Florida                  Not Adopted
# 10               Georgia                  Not Adopted
# 11                Hawaii      Adopted and Implemented
# 12                 Idaho      Adopted and Implemented
# 13              Illinois      Adopted and Implemented
# 14               Indiana      Adopted and Implemented
# 15                  Iowa      Adopted and Implemented
# ...

# %%
over200 = df[(df['Confirmed'] >= 200) & (df['Country_Region'] == 'US')]
over200['DeathToConf'] = over200['Deaths'] / df['Confirmed']
over200
# Out:
# /Users/dineshmurali/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#          FIPS                Admin2        Province_State Country_Region  \
# 18     6001.0               Alameda            California             US
# 20    36001.0                Albany              New York             US
# 31    42003.0             Allegheny          Pennsylvania             US
# 59     8005.0              Arapahoe              Colorado             US
# 90    24005.0             Baltimore              Maryland             US
# 91    24510.0        Baltimore City              Maryland             US
# ...

# %%
#hospital beds: https://docs.google.com/spreadsheets/d/1xAyBFTrlxSsTKQS7IDyr_Ah4JLBYj6_HX6ijKdm4fAY/edit#gid=0
#hospitals https://data.medicare.gov/widgets/xubh-q36u , already downloaded

# %%
medicaidExp.rename(columns={'State':'Province_State'},inplace=True)

# %%
medicaidExp
# Out:
#           Province_State             Expansion Status  \
# 0                Alabama                  Not Adopted
# 1                 Alaska      Adopted and Implemented
# 2                Arizona      Adopted and Implemented
# 3               Arkansas      Adopted and Implemented
# 4             California      Adopted and Implemented
# 5               Colorado      Adopted and Implemented
# 6            Connecticut      Adopted and Implemented
# 7               Delaware      Adopted and Implemented
# 8   District of Columbia      Adopted and Implemented
# 9                Florida                  Not Adopted
# 10               Georgia                  Not Adopted
# 11                Hawaii      Adopted and Implemented
# 12                 Idaho      Adopted and Implemented
# 13              Illinois      Adopted and Implemented
# 14               Indiana      Adopted and Implemented
# 15                  Iowa      Adopted and Implemented
# ...

# %%
usa.dtypes
# Out:
# FIPS              float64
# Admin2             object
# Province_State     object
# Country_Region     object
# Last_Update        object
# Lat               float64
# Long_             float64
# Confirmed           int64
# Deaths              int64
# Recovered           int64
# Active              int64
# Combined_Key       object
# dtype: object

# %%
medicaidExp.dtypes
# Out:
# Province_State              object
# Expansion Status            object
# Description                 object
# Implemented_Dt      datetime64[ns]
# dtype: object

# %%
usaMedicaid = pd.merge(usa,medicaidExp, on='Province_State', how='left').drop(columns=['Expansion Status','Description'])
usaMedicaid
# Out:
#          FIPS           Admin2            Province_State Country_Region  \
# 0     45001.0        Abbeville            South Carolina             US
# 1     22001.0           Acadia                 Louisiana             US
# 2     51001.0         Accomack                  Virginia             US
# 3     16001.0              Ada                     Idaho             US
# 4     19001.0            Adair                      Iowa             US
# 5     29001.0            Adair                  Missouri             US
# 6     40001.0            Adair                  Oklahoma             US
# 7      8001.0            Adams                  Colorado             US
# 8     16003.0            Adams                     Idaho             US
# 9     17001.0            Adams                  Illinois             US
# 10    18001.0            Adams                   Indiana             US
# 11    28001.0            Adams               Mississippi             US
# ...

# %%
import numpy as np
usaMedicaid['Is_Medicaid'] = ['NoMedicaid' if pd.isnull(impdt) else 'Medicaid' for impdt in usaMedicaid['Implemented_Dt']]

# %%
usaMedicaid
# Out:
#          FIPS           Admin2            Province_State Country_Region  \
# 0     45001.0        Abbeville            South Carolina             US
# 1     22001.0           Acadia                 Louisiana             US
# 2     51001.0         Accomack                  Virginia             US
# 3     16001.0              Ada                     Idaho             US
# 4     19001.0            Adair                      Iowa             US
# 5     29001.0            Adair                  Missouri             US
# 6     40001.0            Adair                  Oklahoma             US
# 7      8001.0            Adams                  Colorado             US
# 8     16003.0            Adams                     Idaho             US
# 9     17001.0            Adams                  Illinois             US
# 10    18001.0            Adams                   Indiana             US
# 11    28001.0            Adams               Mississippi             US
# ...

# %%
#4/2
wMedicaidConf = usaMedicaid.groupby(['Province_State','Is_Medicaid'])['Confirmed','Deaths'].sum()
wMedicaidConf
# Out:
#                                       Confirmed  Deaths
# Province_State           Is_Medicaid
# Alabama                  NoMedicaid        1233      32
# Alaska                   Medicaid           143       3
# Arizona                  Medicaid          1715      32
# Arkansas                 Medicaid           643      12
# California               Medicaid         10773     238
# Colorado                 Medicaid          3342      80
# Connecticut              Medicaid          3824     112
# Delaware                 Medicaid           393      12
# Diamond Princess         NoMedicaid          49       0
# District of Columbia     Medicaid           653      12
# Florida                  NoMedicaid        9008     164
# Georgia                  NoMedicaid        5348     163
# Grand Princess           NoMedicaid         103       3
# Guam                     NoMedicaid          82       3
# Hawaii                   Medicaid           256       1
# ...

# %%
#4/3
wMedicaidConf = usaMedicaid.groupby(['Province_State','Is_Medicaid'])['Confirmed','Deaths'].sum()
wMedicaidConf
# Out:
#                                       Confirmed  Deaths
# Province_State           Is_Medicaid
# Alabama                  NoMedicaid        1495      38
# Alaska                   Medicaid           157       3
# Arizona                  Medicaid          1937      41
# Arkansas                 Medicaid           704      12
# California               Medicaid         12004     265
# Colorado                 Medicaid          3742      97
# Connecticut              Medicaid          4914     131
# Delaware                 Medicaid           450      14
# Diamond Princess         NoMedicaid          49       0
# District of Columbia     Medicaid           757      15
# Florida                  NoMedicaid       10268     170
# Georgia                  NoMedicaid        5831     184
# Grand Princess           NoMedicaid         103       3
# Guam                     NoMedicaid          84       4
# Hawaii                   Medicaid           319       3
# ...

# %%
#4/2
wMedicaidConfOver1k = wMedicaidConf[wMedicaidConf['Confirmed'] > 1000]
wMedicaidConfOver1k
# Out:
#                             Confirmed  Deaths
# Province_State Is_Medicaid
# Alabama        NoMedicaid        1233      32
# Arizona        Medicaid          1715      32
# California     Medicaid         10773     238
# Colorado       Medicaid          3342      80
# Connecticut    Medicaid          3824     112
# Florida        NoMedicaid        9008     164
# Georgia        NoMedicaid        5348     163
# Illinois       Medicaid          7695     163
# Indiana        Medicaid          3038      78
# Louisiana      Medicaid          9159     310
# Maryland       Medicaid          2331      36
# Massachusetts  Medicaid          8966     154
# Michigan       Medicaid         10791     417
# Mississippi    NoMedicaid        1177      26
# Missouri       NoMedicaid        1857      22
# Nevada         Medicaid          1463      38
# New Jersey     Medicaid         25590     537
# New York       Medicaid         92506    2373
# North Carolina NoMedicaid        1977      21
# ...

# %%
#4/3
wMedicaidConfOver1k = wMedicaidConf[wMedicaidConf['Confirmed'] > 1000]
wMedicaidConfOver1k
# Out:
#                             Confirmed  Deaths
# Province_State Is_Medicaid
# Alabama        NoMedicaid        1495      38
# Arizona        Medicaid          1937      41
# California     Medicaid         12004     265
# Colorado       Medicaid          3742      97
# Connecticut    Medicaid          4914     131
# Florida        NoMedicaid       10268     170
# Georgia        NoMedicaid        5831     184
# Illinois       Medicaid          8904     210
# Indiana        Medicaid          3437     102
# Louisiana      Medicaid         10297     370
# Maryland       Medicaid          2758      43
# Massachusetts  Medicaid         10402     192
# Michigan       Medicaid         12744     479
# Mississippi    NoMedicaid        1358      29
# Missouri       NoMedicaid        1864      25
# Nevada         Medicaid          1514      43
# New Jersey     Medicaid         29895     646
# New York       Medicaid        102987    2935
# North Carolina NoMedicaid        2251      27
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set(style="ticks", color_codes=True)

# %%
#4/2
wMedicaidConfOver1k['Mortality'] = wMedicaidConfOver1k['Deaths'] / wMedicaidConfOver1k['Confirmed'] * 100
wMedicaidConfOver1k
# Out:
# /Users/dineshmurali/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
#                             Confirmed  Deaths  Mortality
# Province_State Is_Medicaid
# Alabama        NoMedicaid        1233      32   2.595296
# Arizona        Medicaid          1715      32   1.865889
# California     Medicaid         10773     238   2.209227
# Colorado       Medicaid          3342      80   2.393776
# Connecticut    Medicaid          3824     112   2.928870
# Florida        NoMedicaid        9008     164   1.820604
# Georgia        NoMedicaid        5348     163   3.047868
# Illinois       Medicaid          7695     163   2.118259
# ...

# %%
#4/3
wMedicaidConfOver1k['Mortality'] = wMedicaidConfOver1k['Deaths'] / wMedicaidConfOver1k['Confirmed'] * 100
wMedicaidConfOver1k
# Out:
# /Users/dineshmurali/miniconda3/lib/python3.5/site-packages/ipykernel/__main__.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   from ipykernel import kernelapp as app
#                             Confirmed  Deaths  Mortality
# Province_State Is_Medicaid
# Alabama        NoMedicaid        1495      38   2.541806
# Arizona        Medicaid          1937      41   2.116675
# California     Medicaid         12004     265   2.207597
# Colorado       Medicaid          3742      97   2.592197
# Connecticut    Medicaid          4914     131   2.665853
# Florida        NoMedicaid       10268     170   1.655629
# Georgia        NoMedicaid        5831     184   3.155548
# Illinois       Medicaid          8904     210   2.358491
# ...

# %%
wMedicaidConfOver1k = wMedicaidConfOver1k.reset_index()
wMedicaidConfOver1k
# Out:
#     Province_State Is_Medicaid  Confirmed  Deaths  Mortality
# 0          Alabama  NoMedicaid       1233      32   2.595296
# 1          Arizona    Medicaid       1715      32   1.865889
# 2       California    Medicaid      10773     238   2.209227
# 3         Colorado    Medicaid       3342      80   2.393776
# 4      Connecticut    Medicaid       3824     112   2.928870
# 5          Florida  NoMedicaid       9008     164   1.820604
# 6          Georgia  NoMedicaid       5348     163   3.047868
# 7         Illinois    Medicaid       7695     163   2.118259
# 8          Indiana    Medicaid       3038      78   2.567479
# 9        Louisiana    Medicaid       9159     310   3.384649
# 10        Maryland    Medicaid       2331      36   1.544402
# 11   Massachusetts    Medicaid       8966     154   1.717600
# 12        Michigan    Medicaid      10791     417   3.864331
# 13     Mississippi  NoMedicaid       1177      26   2.209006
# ...

# %%
mortByMedi = wMedicaidConfOver1k.groupby('Is_Medicaid')['Mortality'].mean()
mortByMedi
# Out:
# Is_Medicaid
# Medicaid      2.398445
# NoMedicaid    1.887288
# Name: Mortality, dtype: float64
