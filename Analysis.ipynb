# %%
import pandas as pd

df = pd.read_csv('csse_covid_19_data/csse_covid_19_daily_reports/03-30-2020.csv')
df.head(10)
# Out:
#       FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0  45001.0  Abbeville  South Carolina             US  2020-03-30 22:52:45
# 1  22001.0     Acadia       Louisiana             US  2020-03-30 22:52:45
# 2  51001.0   Accomack        Virginia             US  2020-03-30 22:52:45
# 3  16001.0        Ada           Idaho             US  2020-03-30 22:52:45
# 4  19001.0      Adair            Iowa             US  2020-03-30 22:52:45
# 5  21001.0      Adair        Kentucky             US  2020-03-30 22:52:45
# 6  29001.0      Adair        Missouri             US  2020-03-30 22:52:45
# 7  40001.0      Adair        Oklahoma             US  2020-03-30 22:52:45
# 8   8001.0      Adams        Colorado             US  2020-03-30 22:52:45
# 9  16003.0      Adams           Idaho             US  2020-03-30 22:52:45
#
#          Lat       Long_  Confirmed  Deaths  Recovered  Active  \
# 0  34.223334  -82.461707          3       0          0       0
# ...

# %%
df.shape
# Out:
# (3439, 12)

# %%
usa = df[df['Country_Region'] == 'US']
usa.shape
# Out:
# (3186, 12)

# %%
usa[usa['Province_State'] == 'Oregon'].shape
# Out:
# (36, 12)

# %%
usa[usa['Province_State'] == 'Oregon']
# Out:
#          FIPS      Admin2 Province_State Country_Region          Last_Update  \
# 118   41001.0       Baker         Oregon             US  2020-03-30 22:52:45
# 186   41003.0      Benton         Oregon             US  2020-03-30 22:52:45
# 512   41005.0   Clackamas         Oregon             US  2020-03-30 22:52:45
# 537   41007.0     Clatsop         Oregon             US  2020-03-30 22:52:45
# 609   41009.0    Columbia         Oregon             US  2020-03-30 22:52:45
# 633   41011.0        Coos         Oregon             US  2020-03-30 22:52:45
# 673   41013.0       Crook         Oregon             US  2020-03-30 22:52:45
# 693   41015.0       Curry         Oregon             US  2020-03-30 22:52:45
# 771   41017.0   Deschutes         Oregon             US  2020-03-30 22:52:45
# 814   41019.0     Douglas         Oregon             US  2020-03-30 22:52:45
# 1042  41021.0     Gilliam         Oregon             US  2020-03-30 22:52:45
# ...

# %%
usa[usa['Province_State'] == 'Oregon'].groupby(['Province_State'])['Confirmed'].sum()
# Out:
# Province_State
# Oregon    606
# Name: Confirmed, dtype: int64

# %%
usa.groupby(['Province_State'])['Confirmed'].sum()
# Out:
# Province_State
# Alabama                       899
# Alaska                        114
# American Samoa                  0
# Arizona                      1157
# Arkansas                      473
# California                   7138
# Colorado                     2311
# Connecticut                  2571
# Delaware                      264
# Diamond Princess               49
# District of Columbia          401
# Florida                      5473
# Georgia                      2808
# Grand Princess                103
# Guam                           58
# Hawaii                        175
# Idaho                         340
# Illinois                     5056
# Indiana                      1786
# Iowa                          424
# Kansas                        372
# Kentucky                      479
# Louisiana                    4025
# Maine                         275
# Maryland                     1413
# Massachusetts                5752
# Michigan                     6498
# ...

# %%
flu = pd.read_csv('/Users/dineshmurali/Documents/FluViewPhase2Data/ILINet.csv')
flu.shape
# Out:
# (1174, 1)

# %%
flu.head(10)
# Out:
#                                                                                                                                              PERCENTAGE OF VISITS FOR INFLUENZA-LIKE-ILLNESS REPORTED BY SENTINEL PROVIDERS
# REGION TYPE REGION YEAR WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS                                     TOTAL PATIENTS
# National    X      1997 40   1.10148        1.21686         179     X         157       205      X         29     570      192                                                            46842
#                         41   1.20007        1.28064         199     X         151       242      X         23     615      191                                                            48023
#                         42   1.37876        1.23906         228     X         153       266      X         34     681      219                                                            54961
# ...

# %%
fluClin = pd.read_csv('/Users/dineshmurali/Documents/FluViewPhase2Data/WHO_NREVSS_Clinical_Labs.csv')
fluClin.head(10)
# Out:
#                                                                                         *Beginning for the 2015-16 season, reports from public health and clinical laboratories are presented separately in the weekly influenza update, FluView. Data from clinical laboratories include the weekly total number of specimens tested, the number of positive influenza test, and the percent positive by influenza type.
# REGION TYPE REGION YEAR WEEK TOTAL SPECIMENS TOTAL A TOTAL B PERCENT POSITIVE PERCENT A                                          PERCENT B
# National    X      2015 40   12029           84      43      1.05578          0.698312                                            0.357469
#                         41   13111           116     54      1.29662          0.884753                                            0.411868
#                         42   13441           97      52      1.10855          0.721672                                            0.386876
# ...

# %%
#https://gis.cdc.gov/grasp/fluview/FluViewPhase2QuickReferenceGuide.pdf
fluStates = pd.read_csv('/Users/dineshmurali/Documents/FluViewPhase2DataAllStates/ILINet.csv')
fluStates.head(100)
# Out:
#                                                                                                                                                            PERCENTAGE OF VISITS FOR INFLUENZA-LIKE-ILLNESS REPORTED BY SENTINEL PROVIDERS
# REGION TYPE REGION               YEAR WEEK % WEIGHTED ILI %UNWEIGHTED ILI AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65 ILITOTAL NUM. OF PROVIDERS                                     TOTAL PATIENTS
# States      Alabama              2010 40   X              2.13477         X       X         X         X        X         X      249      35                                                             11664
#             Alaska               2010 40   X              0.875146        X       X         X         X        X         X      15       7                                                               1714
# ...

# %%
fluStates.shape
# Out:
# (26494, 1)

# %%
fluStates.dtypes
# Out:
# PERCENTAGE OF VISITS FOR INFLUENZA-LIKE-ILLNESS REPORTED BY SENTINEL PROVIDERS    object
# dtype: object

# %%
fluAllSts = fluStates.reset_index()
fluAllSts.head(100)
# Out:
#         level_0               level_1 level_2 level_3         level_4  \
# 0   REGION TYPE                REGION    YEAR    WEEK  % WEIGHTED ILI
# 1        States               Alabama    2010      40               X
# 2        States                Alaska    2010      40               X
# 3        States               Arizona    2010      40               X
# 4        States              Arkansas    2010      40               X
# 5        States            California    2010      40               X
# 6        States              Colorado    2010      40               X
# 7        States           Connecticut    2010      40               X
# 8        States              Delaware    2010      40               X
# 9        States  District of Columbia    2010      40               X
# 10       States               Florida    2010      40               X
# 11       States               Georgia    2010      40               X
# ...

# %%
fluAllSts[1:]
# Out:
#       level_0                                       level_1 level_2 level_3  \
# 1      States                                       Alabama    2010      40
# 2      States                                        Alaska    2010      40
# 3      States                                       Arizona    2010      40
# 4      States                                      Arkansas    2010      40
# 5      States                                    California    2010      40
# 6      States                                      Colorado    2010      40
# 7      States                                   Connecticut    2010      40
# 8      States                                      Delaware    2010      40
# 9      States                          District of Columbia    2010      40
# 10     States                                       Florida    2010      40
# 11     States                                       Georgia    2010      40
# ...

# %%
fluAllSts.iloc[0]
# Out:
# level_0                                                                                 REGION TYPE
# level_1                                                                                      REGION
# level_2                                                                                        YEAR
# level_3                                                                                        WEEK
# level_4                                                                              % WEIGHTED ILI
# level_5                                                                             %UNWEIGHTED ILI
# level_6                                                                                     AGE 0-4
# level_7                                                                                   AGE 25-49
# level_8                                                                                   AGE 25-64
# ...

# %%
fluFinal = fluAllSts[1:].copy()
fluFinal.head(10)
# Out:
#    level_0               level_1 level_2 level_3 level_4    level_5 level_6  \
# 1   States               Alabama    2010      40       X    2.13477       X
# 2   States                Alaska    2010      40       X   0.875146       X
# 3   States               Arizona    2010      40       X   0.674721       X
# 4   States              Arkansas    2010      40       X   0.696056       X
# 5   States            California    2010      40       X    1.95412       X
# 6   States              Colorado    2010      40       X   0.660684       X
# 7   States           Connecticut    2010      40       X  0.0783085       X
# 8   States              Delaware    2010      40       X   0.100125       X
# 9   States  District of Columbia    2010      40       X    2.80877       X
# 10  States               Florida    2010      40       X          X       X
#
#    level_7 level_8 level_9 level_10 level_11 level_12 level_13  \
# 1        X       X       X        X        X      249       35
# ...

# %%
fluFinal.columns = fluAllSts.iloc[0]

# %%
fluFinal.head(10)
# Out:
# 0  REGION TYPE                REGION  YEAR WEEK % WEIGHTED ILI  \
# 1       States               Alabama  2010   40              X
# 2       States                Alaska  2010   40              X
# 3       States               Arizona  2010   40              X
# 4       States              Arkansas  2010   40              X
# 5       States            California  2010   40              X
# 6       States              Colorado  2010   40              X
# 7       States           Connecticut  2010   40              X
# 8       States              Delaware  2010   40              X
# 9       States  District of Columbia  2010   40              X
# 10      States               Florida  2010   40              X
#
# 0  %UNWEIGHTED ILI AGE 0-4 AGE 25-49 AGE 25-64 AGE 5-24 AGE 50-64 AGE 65  \
# 1          2.13477       X         X         X        X         X      X
# 2         0.875146       X         X         X        X         X      X
# ...

# %%
#https://www.kff.org/medicaid/issue-brief/status-of-state-medicaid-expansion-decisions-interactive-map/
medicaidExp = pd.read_csv('medicaidexpansionmap.csv')
medicaidExp
# Out:
#                    State             Expansion Status  \
# 0                Alabama                  Not Adopted
# 1                 Alaska      Adopted and Implemented
# 2                Arizona      Adopted and Implemented
# 3               Arkansas      Adopted and Implemented
# 4             California      Adopted and Implemented
# 5               Colorado      Adopted and Implemented
# 6            Connecticut      Adopted and Implemented
# 7               Delaware      Adopted and Implemented
# 8   District of Columbia      Adopted and Implemented
# 9                Florida                  Not Adopted
# 10               Georgia                  Not Adopted
# 11                Hawaii      Adopted and Implemented
# 12                 Idaho      Adopted and Implemented
# 13              Illinois      Adopted and Implemented
# 14               Indiana      Adopted and Implemented
# 15                  Iowa      Adopted and Implemented
# ...

# %%
medicaidExp.fillna('NA', inplace=True)

# %%
import re
[desc for desc in medicaidExp['Description'] if desc.find('*[0-9]//[0-9]//[0-9][0-9][0-9][0-9]*')]
# Out:
# ['NA',
#  'Implemented expansion on 9/1/2015\n',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 1/1/2014 \n',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 1/1/2014\n',
#  'NA',
#  'NA',
#  'Implemented expansion on 1/1/2014\n',
#  'Expansion coverage implemented 1/1/2020 (enrollment began 11/1/2019)',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 2/1/2015\n',
#  'Implemented expansion on 1/1/2014\n',
#  'NA',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 7/1/2016\n',
#  'Implemented expansion on 1/10/2019 with coverage retroactive to 7/2/2018',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 1/1/2014\n',
#  'Implemented expansion on 4/1/2014\n',
#  'Implemented expansion on 1/1/2014\n',
#  'NA',
#  'NA',
# ...
